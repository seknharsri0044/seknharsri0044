# %%
# 1.	Import the dataset using Pandas from above mentioned url.
import pandas as pd
import numpy as np

# %%
Url = 'https://raw.githubusercontent.com/SR1608/Datasets/main/covid-data.csv'
df=pd.read_csv(Url)
df.head()
# Out:
#   iso_code continent     location      date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  31/12/19          NaN        0.0
# 1      AFG      Asia  Afghanistan  01/01/20          NaN        0.0
# 2      AFG      Asia  Afghanistan  02/01/20          NaN        0.0
# 3      AFG      Asia  Afghanistan  03/01/20          NaN        0.0
# 4      AFG      Asia  Afghanistan  04/01/20          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         0.0                  NaN
# 1                 NaN           NaN         0.0                  NaN
# 2                 NaN           NaN         0.0                  NaN
# 3                 NaN           NaN         0.0                  NaN
# 4                 NaN           NaN         0.0                  NaN
#
#             ...             gdp_per_capita  extreme_poverty  \
# 0           ...                   1803.987              NaN
# ...

# %%
#a.	Find no. of rows & columns in the dataset
df.shape
# Out:
# (57394, 49)

# %%
#b.	Data types of columns.
df.dtypes
# Out:
# iso_code                               object
# continent                              object
# location                               object
# date                                   object
# total_cases                           float64
# new_cases                             float64
# new_cases_smoothed                    float64
# total_deaths                          float64
# new_deaths                            float64
# new_deaths_smoothed                   float64
# total_cases_per_million               float64
# new_cases_per_million                 float64
# new_cases_smoothed_per_million        float64
# total_deaths_per_million              float64
# new_deaths_per_million                float64
# new_deaths_smoothed_per_million       float64
# reproduction_rate                     float64
# icu_patients                          float64
# icu_patients_per_million              float64
# hosp_patients                         float64
# ...

# %%
#c.	Info & describe of data in dataframe.

df.describe(include = 'all')
# Out:
#        iso_code continent location      date   total_cases      new_cases  \
# count     57071     56748    57394     57394  5.375800e+04   56465.000000
# unique      215         6      216       323           NaN            NaN
# top         ITA    Europe    Italy  30/10/20           NaN            NaN
# freq        323     14828      323       215           NaN            NaN
# mean        NaN       NaN      NaN       NaN  1.677974e+05    1953.576941
# std         NaN       NaN      NaN       NaN  1.693038e+06   18269.650340
# min         NaN       NaN      NaN       NaN  1.000000e+00   -8261.000000
# 25%         NaN       NaN      NaN       NaN  1.800000e+02       0.000000
# 50%         NaN       NaN      NaN       NaN  2.070000e+03      14.000000
# 75%         NaN       NaN      NaN       NaN  2.235675e+04     235.000000
# max         NaN       NaN      NaN       NaN  5.515465e+07  646281.000000
#
#         new_cases_smoothed  total_deaths    new_deaths  new_deaths_smoothed  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57394 entries, 0 to 57393
# Data columns (total 49 columns):
# iso_code                              57071 non-null object
# continent                             56748 non-null object
# location                              57394 non-null object
# date                                  57394 non-null object
# total_cases                           53758 non-null float64
# new_cases                             56465 non-null float64
# new_cases_smoothed                    55652 non-null float64
# total_deaths                          44368 non-null float64
# new_deaths                            56465 non-null float64
# new_deaths_smoothed                   55652 non-null float64
# total_cases_per_million               53471 non-null float64
# new_cases_per_million                 56401 non-null float64
# new_cases_smoothed_per_million        55587 non-null float64
# total_deaths_per_million              44096 non-null float64
# ...

# %%
#a.	Find count of unique values in location column.
df['location'].value_counts()
# Out:
# Italy                              323
# Czech Republic                     323
# China                              323
# Malaysia                           323
# Dominican Republic                 323
# Kuwait                             323
# Israel                             323
# Macedonia                          323
# Ireland                            323
# Greece                             323
# Thailand                           323
# Iceland                            323
# Philippines                        323
# Austria                            323
# Monaco                             323
# Romania                            323
# South Korea                        323
# Iraq                               323
# Afghanistan                        323
# Denmark                            323
# Norway                             323
# Finland                            323
# Brazil                             323
# Luxembourg                         323
# ...

# %%
#b.	Find which continent has maximum frequency using values counts.
df['continent'].value_counts()
# Out:
# Europe           14828
# Africa           13637
# Asia             13528
# North America     9116
# South America     3404
# Oceania           2235
# Name: continent, dtype: int64

# %%
#c.	Find maximum & mean value in 'total_cases'.
df['total_cases'].value_counts().mean()
# Out:
# 2.371118560338744

# %%
df['total_cases'].value_counts().mean()
# Out:
# 2.371118560338744

# %%
df.groupby(by = 'continent').gdp_per_capita.sum().sort_values().head(1)
# Out:
# continent
# Oceania    2.972208e+07
# Name: gdp_per_capita, dtype: float64

# %%
#.	Find which continent has maximum 'human_development_index'.
df.groupby('continent')['human_development_index'].max().head(1)
# Out:
# continent
# Africa    0.797
# Name: human_development_index, dtype: float64

# %%
df.groupby('continent')['gdp_per_capita'].min().head(1)
# Out:
# continent
# Africa    661.24
# Name: gdp_per_capita, dtype: float64

# %%
#4.	Filter the dataframe with only this columns ['continent','location','date','total_cases','total_deaths','gdp_per_ca
#pita','human_development_index'] and update the data frame.
new_dataframe=df.filter(items=['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index'])
new_dataframe
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# 5          Asia    Afghanistan  05/01/20          NaN           NaN
# 6          Asia    Afghanistan  06/01/20          NaN           NaN
# 7          Asia    Afghanistan  07/01/20          NaN           NaN
# 8          Asia    Afghanistan  08/01/20          NaN           NaN
# 9          Asia    Afghanistan  09/01/20          NaN           NaN
# 10         Asia    Afghanistan  10/01/20          NaN           NaN
# 11         Asia    Afghanistan  11/01/20          NaN           NaN
# 12         Asia    Afghanistan  12/01/20          NaN           NaN
# ...

# %%
#a.	Remove all duplicates observations
new_dataframe.drop_duplicates(inplace = True)
new_dataframe
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# 5          Asia    Afghanistan  05/01/20          NaN           NaN
# 6          Asia    Afghanistan  06/01/20          NaN           NaN
# 7          Asia    Afghanistan  07/01/20          NaN           NaN
# 8          Asia    Afghanistan  08/01/20          NaN           NaN
# 9          Asia    Afghanistan  09/01/20          NaN           NaN
# 10         Asia    Afghanistan  10/01/20          NaN           NaN
# 11         Asia    Afghanistan  11/01/20          NaN           NaN
# 12         Asia    Afghanistan  12/01/20          NaN           NaN
# ...

# %%
#b.	Find missing values in all columns
new_dataframe.isnull()
# Out:
#        continent  location   date  total_cases  total_deaths  gdp_per_capita  \
# 0          False     False  False         True          True           False
# 1          False     False  False         True          True           False
# 2          False     False  False         True          True           False
# 3          False     False  False         True          True           False
# 4          False     False  False         True          True           False
# 5          False     False  False         True          True           False
# 6          False     False  False         True          True           False
# 7          False     False  False         True          True           False
# 8          False     False  False         True          True           False
# 9          False     False  False         True          True           False
# 10         False     False  False         True          True           False
# ...

# %%
#c.	Remove all observations where continent column value is missing
new_dataframe.dropna(axis = 1)
# Out:
#             location      date
# 0        Afghanistan  31/12/19
# 1        Afghanistan  01/01/20
# 2        Afghanistan  02/01/20
# 3        Afghanistan  03/01/20
# 4        Afghanistan  04/01/20
# 5        Afghanistan  05/01/20
# 6        Afghanistan  06/01/20
# 7        Afghanistan  07/01/20
# 8        Afghanistan  08/01/20
# 9        Afghanistan  09/01/20
# 10       Afghanistan  10/01/20
# 11       Afghanistan  11/01/20
# 12       Afghanistan  12/01/20
# 13       Afghanistan  13/01/20
# 14       Afghanistan  14/01/20
# 15       Afghanistan  15/01/20
# 16       Afghanistan  16/01/20
# 17       Afghanistan  17/01/20
# 18       Afghanistan  18/01/20
# 19       Afghanistan  19/01/20
# 20       Afghanistan  20/01/20
# 21       Afghanistan  21/01/20
# 22       Afghanistan  22/01/20
# 23       Afghanistan  23/01/20
# 24       Afghanistan  24/01/20
# 25       Afghanistan  25/01/20
# 26       Afghanistan  26/01/20
# 27       Afghanistan  27/01/20
# 28       Afghanistan  28/01/20
# ...

# %%
#d.	Fill all missing values with 0
new_dataframe.fillna(0).head(5)
# Out:
#   continent     location       date  total_cases  total_deaths  \
# 0      Asia  Afghanistan 2019-12-31          0.0           0.0
# 1      Asia  Afghanistan 2020-01-01          0.0           0.0
# 2      Asia  Afghanistan 2020-02-01          0.0           0.0
# 3      Asia  Afghanistan 2020-03-01          0.0           0.0
# 4      Asia  Afghanistan 2020-04-01          0.0           0.0
#
#    gdp_per_capita  human_development_index  month
# 0        1803.987                    0.498     12
# 1        1803.987                    0.498      1
# 2        1803.987                    0.498      2
# 3        1803.987                    0.498      3
# 4        1803.987                    0.498      4

# %%
#a.	Convert date column in datetime format using pandas.to_datetime
new_dataframe['date'] = pd.to_datetime(df['date'])
new_dataframe
# Out:
#       continent       location       date  total_cases  total_deaths  \
# 0          Asia    Afghanistan 2019-12-31          NaN           NaN
# 1          Asia    Afghanistan 2020-01-01          NaN           NaN
# 2          Asia    Afghanistan 2020-02-01          NaN           NaN
# 3          Asia    Afghanistan 2020-03-01          NaN           NaN
# 4          Asia    Afghanistan 2020-04-01          NaN           NaN
# 5          Asia    Afghanistan 2020-05-01          NaN           NaN
# 6          Asia    Afghanistan 2020-06-01          NaN           NaN
# 7          Asia    Afghanistan 2020-07-01          NaN           NaN
# 8          Asia    Afghanistan 2020-08-01          NaN           NaN
# 9          Asia    Afghanistan 2020-09-01          NaN           NaN
# 10         Asia    Afghanistan 2020-10-01          NaN           NaN
# 11         Asia    Afghanistan 2020-11-01          NaN           NaN
# 12         Asia    Afghanistan 2020-12-01          NaN           NaN
# ...

# %%
#b.	Create new column month after extracting month data from column date.
new_dataframe['month'] = pd.DatetimeIndex(df['date']).month
new_dataframe.head()
# Out:
#   continent     location       date  total_cases  total_deaths  \
# 0      Asia  Afghanistan 2019-12-31          NaN           NaN
# 1      Asia  Afghanistan 2020-01-01          NaN           NaN
# 2      Asia  Afghanistan 2020-02-01          NaN           NaN
# 3      Asia  Afghanistan 2020-03-01          NaN           NaN
# 4      Asia  Afghanistan 2020-04-01          NaN           NaN
#
#    gdp_per_capita  human_development_index  month
# 0        1803.987                    0.498     12
# 1        1803.987                    0.498      1
# 2        1803.987                    0.498      2
# 3        1803.987                    0.498      3
# 4        1803.987                    0.498      4

# %%
#a.	Find max value in all columns using groupby function on 'continent colum Tip: use reset_index() after applying groupby

df_grouped = new_dataframe.groupby(['continent']).max()
df_grouped
# Out:
#                                    location       date  total_cases  \
# continent
# Africa                             Zimbabwe 2020-12-11     752269.0
# Asia                                  Yemen 2020-12-11    8874290.0
# Europe                              Vatican 2020-12-11    1991233.0
# North America  United States Virgin Islands 2020-12-11   11205486.0
# Oceania                   Wallis and Futuna 2020-12-11      27750.0
# South America                     Venezuela 2020-12-11    5876464.0
#
#                total_deaths  gdp_per_capita  human_development_index  month
# continent
# Africa              20314.0       26382.287                    0.797     12
# Asia               130519.0      116935.600                    0.933     12
# Europe              52147.0       94277.965                    0.953     12
# North America      247220.0       54225.446                    0.926     12
# Oceania               907.0       44648.710                    0.939     12
# ...

# %%
#b.	Store the result in a new dataframe named 'df_groupby'. (Use df_groupby dataframe for all further analysis)
df_groupby==df_grouped  
df_groupby
# Out:
#                                    location       date  total_cases  \
# continent
# Africa                             Zimbabwe 2020-12-11     752269.0
# Asia                                  Yemen 2020-12-11    8874290.0
# Europe                              Vatican 2020-12-11    1991233.0
# North America  United States Virgin Islands 2020-12-11   11205486.0
# Oceania                   Wallis and Futuna 2020-12-11      27750.0
# South America                     Venezuela 2020-12-11    5876464.0
#
#                total_deaths  gdp_per_capita  human_development_index  month  \
# continent
# Africa              20314.0       26382.287                    0.797     12
# Asia               130519.0      116935.600                    0.933     12
# Europe              52147.0       94277.965                    0.953     12
# North America      247220.0       54225.446                    0.926     12
# Oceania               907.0       44648.710                    0.939     12
# ...

# %%
#a.	Create a new feature 'total_deaths_to_total_cases' by ratio of 'total_deaths' column to 'total_cases'
df_groupby['ratio'] = df_groupby['total_deaths'] / df_groupby['total_cases'] 
df_groupby['ratio']
# Out:
# continent
# Africa           0.027004
# Asia             0.014708
# Europe           0.026188
# North America    0.022062
# Oceania          0.032685
# South America    0.028251
# Name: ratio, dtype: float64

# %%
#a.	Perform Univariate analysis on 'gdp_per_capita' column by plotting
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
plt.scatter(df_groupby.index, df_groupby('gdp_per_capita'))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-193e4dfab28f> in <module>()
# ----> 1 plt.scatter(df_groupby.index, df_groupby('gdp_per_capita'))
#       2 plt.show()
#
# TypeError: 'DataFrame' object is not callable

# %%
#b.	Plot a scatter plot of 'total_cases' & 'gdp_per_capita'
sns.scatterplot(data =df_groupby, x = "total_cases", y = "gdp_per_capita")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-285a3c80ad07> in <module>()
#       1 #b.     Plot a scatter plot of 'total_cases' & 'gdp_per_capita'
# ----> 2 sns.scatterplot(data =df_groupby, x = "total_cases", y = "gdp_per_capita")
#       3
#       4 plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'scatterplot'
