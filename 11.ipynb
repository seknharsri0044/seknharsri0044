# %%
import re
class myfood():
    def menu(self):
        print("Welcome to myfood")
        print("""
          ----MAIN MENU----
        1. REGISTER
        2. LOGIN 
        3. EXIT""")
   
    
    def user_register(self):
        input("enter your full name:")
        phone_no= input("enter your phone number:")
        pattern=re.compile('(0|91)?[-\s]?[6-9][0-9]{9}')
        if pattern.match(phone_no):
            mail_id=input("enter your gmail:")
            m=re.compile("\w[ A-Za-z 0-9]*@gmail.com")
            if m.match(mail_id):
                print("enter your adders:")
                input("enter your state:")
                input("enter your distric:")
                input("enter your house no:")
                input("enter your street name:")
                input("enter your road number :")
                input("enter  your pin code:")
                password=input("enter your password:")
                p=re.compile("\w[A-Z a-z 0-9 ]*[%,$,@,#]$")
                if p.match(password):
                    if len(password)>8:
                        print("thank you for registration" )

                    else:  
                        print("set password more than 8 characters")
                else:
                    print("please set strong password")

            else:
                print("enter correct mail id")

        else:
            print("enter correct phone number")
    def user_login():

        password=input("enter your password:")

        if password==p:


            print('''   1.Place New Order
            2.Order history
            3.Update profile''')
            n = int(input("Enter your choice: "))

            if (n == 1):
                input("enter your favourate restaurant name:")
                l=({1:"{Tandoori Chicken:{4 pieces:INR.240}}",
                   2:"{Vegan Burger:{1pieces:INR.320}}",
                   3:"{Truffle Cake:{500 gm:INR.900}}"})
                print(l)
                s=int(input("enter your choice from 1 to 3:"))
                print(l[s])

        else:
            print("enter correct password")
    def order_history():
        print("order history:",l[s])
        
            
            
    def admin_login():
            items_list=({1:"{Tandoori Chicken:{4 pieces:INR.240}}",
                   2:"{Vegan Burger:{1pieces:INR.320}}",
                   3:"{Truffle Cake:{500 gm:INR.900}}"})
            print("items:",items_list)
            discount=(cost/100)*0.15
            print(discount)
            remove_items=items_list.del(s)
            print(remove_items)
    def update():
        print("update your profile")
         input("enter your full name:")
        phone_no= input("enter your phone number:")
        pattern=re.compile('(0|91)?[-\s]?[6-9][0-9]{9}')
        if pattern.match(phone_no):
            mail_id=input("enter your gmail:")
            m=re.compile("\w[ A-Za-z 0-9]*@gmail.com")
            if m.match(mail_id):
                print("enter your adders:")
                input("enter your state:")
                input("enter your distric:")
                input("enter your house no:")
                input("enter your street name:")
                input("enter your road number :")
                input("enter  your pin code:")
                password=input("enter your password:")
                p=re.compile("\w[A-Z a-z 0-9 ]*[%,$,@,#]$")
                if p.match(password):
                    if len(password)>8:
                        print("thank you for registration" )

                    else:  
                        print("set password more than 8 characters")
                else:
                    print("please set strong password")

            else:
                print("enter correct mail id")

        else:
            print("enter correct phone number")
        
    def exit:
        print("thanks for searching")
        
s=myfood()
s.register()
s.user_login()
s.admin_login
s.exit()
# Out:
# Welcome to myfood
#
#           ----MAIN MENU----
#         1. REGISTER
#         2. LOGIN
#         3. EXIT

# %%
s.register()
# Out:
# enter your full name:dfdsfsf
# enter your phone number:9133898009
# enter your gmail:sekharsri0044@gmail.com
# enter your adders:
# enter your state:as
# enter your distric:asas
# enter your house no:asa
# enter your street name:aa
# enter your road number :asa
# enter  your pin code:aasqs
# enter your password:
# please set strong password

# %%
 p="sekharsri44"
o=()
def user_login():

    password=input("enter your password:")
   
    if password==p:
        
    
        print('''   1.Place New Order
        2.Order history
        3.Update profile''')
        n = int(input("Enter your choice: "))
      
        if (n == 1):
            input("enter your favourate restaurant name:")
            l=({1:"{Tandoori Chicken:{4 pieces:INR.240}}",
               2:"{Vegan Burger:{1pieces:INR.320}}",
               3:"{Truffle Cake:{500 gm:INR.900}}"})
            print(l)
            s=int(input("enter your choice from 1 to 3:"))
            print(l[s])
            
    else:
        print("enter correct password")
                  
                  
a=user_login()
a
